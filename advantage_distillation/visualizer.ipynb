# %%
import matplotlib.pyplot as plt
import pandas as pd
import scienceplots

plt.style.use(["science"])

# %%
data = pd.read_csv("depolarization_AD.csv")

# %%
plt.scatter(data["dep_lst"], data["sk_raw_lst"], label="one-way", s=5)
plt.scatter(data["dep_lst"], data["sk_AD_lst"], label="AD", s=5)
plt.legend(loc="best")
plt.savefig("result.pdf", format="pdf", bbox_inches="tight")
