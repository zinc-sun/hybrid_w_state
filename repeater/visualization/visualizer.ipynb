# %%
import matplotlib.pyplot as plt
import scienceplots
import pandas as pd
import glob
import os

plt.style.use(['science'])

pra_params = {
    'figure.figsize': (4.725, 3.5),
    'font.size': 12,
    'text.usetex': True,            
    'font.family': 'serif',         
    'font.serif': ['Computer Modern Roman'], 
    
}

plt.rcParams.update(pra_params)

# %%
file_paths = glob.glob('data/*.csv')
data_dict = {}

for path in file_paths:
    file_name = os.path.basename(path)       
    label = os.path.splitext(file_name)[0]  
    data_dict[label] = pd.read_csv(path)

# %%
d_lst = data_dict['atom_based_p_l_0_5']['distance_km'].to_numpy()

# local loss = 0.01
sk_atom_based_0_01_level_0  = data_dict['atom_based_p_l_0_01']['keyrate_bps_level_0'].to_numpy()
sk_atom_based_0_01_level_1  = data_dict['atom_based_p_l_0_01']['keyrate_bps_level_1'].to_numpy()
sk_atom_based_0_01_level_2  = data_dict['atom_based_p_l_0_01']['keyrate_bps_level_2'].to_numpy()

sk_hybrid_0_01_level_0      = data_dict['hybrid_p_l_0_01']['keyrate_bps_level_0'].to_numpy()
sk_hybrid_0_01_level_1      = data_dict['hybrid_p_l_0_01']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_01_level_2      = data_dict['hybrid_p_l_0_01']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_01_level_0_AD  = data_dict['atom_based_p_l_0_01_AD']['keyrate_bps_level_0'].to_numpy()
sk_atom_based_0_01_level_1_AD  = data_dict['atom_based_p_l_0_01_AD']['keyrate_bps_level_1'].to_numpy()
sk_atom_based_0_01_level_2_AD  = data_dict['atom_based_p_l_0_01_AD']['keyrate_bps_level_2'].to_numpy()

sk_hybrid_0_01_level_0_AD      = data_dict['hybrid_p_l_0_01_AD']['keyrate_bps_level_0'].to_numpy()
sk_hybrid_0_01_level_1_AD      = data_dict['hybrid_p_l_0_01_AD']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_01_level_2_AD      = data_dict['hybrid_p_l_0_01_AD']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_01_GHZ_level_1  = data_dict['atom_based_GHZ_p_l_0_01_level_1']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_01_GHZ_level_1  = data_dict['hybrid_GHZ_p_l_0_01_level_1']['keyrate_bps_level_1'].to_numpy()

sk_atom_based_0_01_GHZ_level_1_AD  = data_dict['atom_based_GHZ_p_l_0_01_level_1_AD']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_01_GHZ_level_1_AD  = data_dict['hybrid_GHZ_p_l_0_01_level_1_AD']['keyrate_bps_level_1'].to_numpy()

sk_atom_based_0_01_GHZ_level_2  = data_dict['atom_based_GHZ_p_l_0_01_level_2']['keyrate_bps_level_2'].to_numpy()
sk_hybrid_0_01_GHZ_level_2  = data_dict['hybrid_GHZ_p_l_0_01_level_2']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_01_GHZ_level_2_AD  = data_dict['atom_based_GHZ_p_l_0_01_level_2_AD']['keyrate_bps_level_2'].to_numpy()
sk_hybrid_0_01_GHZ_level_2_AD  = data_dict['hybrid_GHZ_p_l_0_01_level_2_AD']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_01_level_0_total = sk_atom_based_0_01_level_0
sk_atom_based_0_01_level_1_total = sk_atom_based_0_01_level_1 + sk_atom_based_0_01_GHZ_level_1
sk_atom_based_0_01_level_2_total = sk_atom_based_0_01_level_2 + sk_atom_based_0_01_GHZ_level_2

sk_atom_based_0_01_level_0_AD_total = sk_atom_based_0_01_level_0_AD
sk_atom_based_0_01_level_1_AD_total = sk_atom_based_0_01_level_1_AD + sk_atom_based_0_01_GHZ_level_1_AD
sk_atom_based_0_01_level_2_AD_total = sk_atom_based_0_01_level_2_AD + sk_atom_based_0_01_GHZ_level_2_AD

sk_hybrid_0_01_level_0_total = sk_hybrid_0_01_level_0
sk_hybrid_0_01_level_1_total = sk_hybrid_0_01_level_1 + sk_hybrid_0_01_GHZ_level_1
sk_hybrid_0_01_level_2_total = sk_hybrid_0_01_level_2 + sk_hybrid_0_01_GHZ_level_2

sk_hybrid_0_01_level_0_AD_total = sk_hybrid_0_01_level_0_AD
sk_hybrid_0_01_level_1_AD_total = sk_hybrid_0_01_level_1_AD + sk_hybrid_0_01_GHZ_level_1_AD
sk_hybrid_0_01_level_2_AD_total = sk_hybrid_0_01_level_2_AD + sk_hybrid_0_01_GHZ_level_2_AD


# local loss = 0.1
sk_atom_based_0_1_level_0  = data_dict['atom_based_p_l_0_1']['keyrate_bps_level_0'].to_numpy()
sk_atom_based_0_1_level_1  = data_dict['atom_based_p_l_0_1']['keyrate_bps_level_1'].to_numpy()
sk_atom_based_0_1_level_2  = data_dict['atom_based_p_l_0_1']['keyrate_bps_level_2'].to_numpy()

sk_hybrid_0_1_level_0      = data_dict['hybrid_p_l_0_1']['keyrate_bps_level_0'].to_numpy()
sk_hybrid_0_1_level_1      = data_dict['hybrid_p_l_0_1']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_1_level_2      = data_dict['hybrid_p_l_0_1']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_1_level_0_AD  = data_dict['atom_based_p_l_0_1_AD']['keyrate_bps_level_0'].to_numpy()
sk_atom_based_0_1_level_1_AD  = data_dict['atom_based_p_l_0_1_AD']['keyrate_bps_level_1'].to_numpy()
sk_atom_based_0_1_level_2_AD  = data_dict['atom_based_p_l_0_1_AD']['keyrate_bps_level_2'].to_numpy()

sk_hybrid_0_1_level_0_AD      = data_dict['hybrid_p_l_0_1_AD']['keyrate_bps_level_0'].to_numpy()
sk_hybrid_0_1_level_1_AD      = data_dict['hybrid_p_l_0_1_AD']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_1_level_2_AD      = data_dict['hybrid_p_l_0_1_AD']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_1_GHZ_level_1  = data_dict['atom_based_GHZ_p_l_0_1_level_1']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_1_GHZ_level_1  = data_dict['hybrid_GHZ_p_l_0_1_level_1']['keyrate_bps_level_1'].to_numpy()

sk_atom_based_0_1_GHZ_level_1_AD  = data_dict['atom_based_GHZ_p_l_0_1_level_1_AD']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_1_GHZ_level_1_AD  = data_dict['hybrid_GHZ_p_l_0_1_level_1_AD']['keyrate_bps_level_1'].to_numpy()

sk_atom_based_0_1_GHZ_level_2  = data_dict['atom_based_GHZ_p_l_0_1_level_2']['keyrate_bps_level_2'].to_numpy()
sk_hybrid_0_1_GHZ_level_2  = data_dict['hybrid_GHZ_p_l_0_1_level_2']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_1_GHZ_level_2_AD  = data_dict['atom_based_GHZ_p_l_0_1_level_2_AD']['keyrate_bps_level_2'].to_numpy()
sk_hybrid_0_1_GHZ_level_2_AD  = data_dict['hybrid_GHZ_p_l_0_1_level_2_AD']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_1_level_0_total = sk_atom_based_0_1_level_0
sk_atom_based_0_1_level_1_total = sk_atom_based_0_1_level_1 + sk_atom_based_0_1_GHZ_level_1
sk_atom_based_0_1_level_2_total = sk_atom_based_0_1_level_2 + sk_atom_based_0_1_GHZ_level_2

sk_atom_based_0_1_level_0_AD_total = sk_atom_based_0_1_level_0_AD
sk_atom_based_0_1_level_1_AD_total = sk_atom_based_0_1_level_1_AD + sk_atom_based_0_1_GHZ_level_1_AD
sk_atom_based_0_1_level_2_AD_total = sk_atom_based_0_1_level_2_AD + sk_atom_based_0_1_GHZ_level_2_AD

sk_hybrid_0_1_level_0_total = sk_hybrid_0_1_level_0
sk_hybrid_0_1_level_1_total = sk_hybrid_0_1_level_1 + sk_hybrid_0_1_GHZ_level_1
sk_hybrid_0_1_level_2_total = sk_hybrid_0_1_level_2 + sk_hybrid_0_1_GHZ_level_2

sk_hybrid_0_1_level_0_AD_total = sk_hybrid_0_1_level_0_AD
sk_hybrid_0_1_level_1_AD_total = sk_hybrid_0_1_level_1_AD + sk_hybrid_0_1_GHZ_level_1_AD
sk_hybrid_0_1_level_2_AD_total = sk_hybrid_0_1_level_2_AD + sk_hybrid_0_1_GHZ_level_2_AD

# local loss = 0.5
sk_atom_based_0_5_level_0  = data_dict['atom_based_p_l_0_5']['keyrate_bps_level_0'].to_numpy()
sk_atom_based_0_5_level_1  = data_dict['atom_based_p_l_0_5']['keyrate_bps_level_1'].to_numpy()
sk_atom_based_0_5_level_2  = data_dict['atom_based_p_l_0_5']['keyrate_bps_level_2'].to_numpy()

sk_hybrid_0_5_level_0      = data_dict['hybrid_p_l_0_5']['keyrate_bps_level_0'].to_numpy()
sk_hybrid_0_5_level_1      = data_dict['hybrid_p_l_0_5']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_5_level_2      = data_dict['hybrid_p_l_0_5']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_5_level_0_AD  = data_dict['atom_based_p_l_0_5_AD']['keyrate_bps_level_0'].to_numpy()
sk_atom_based_0_5_level_1_AD  = data_dict['atom_based_p_l_0_5_AD']['keyrate_bps_level_1'].to_numpy()
sk_atom_based_0_5_level_2_AD  = data_dict['atom_based_p_l_0_5_AD']['keyrate_bps_level_2'].to_numpy()

sk_hybrid_0_5_level_0_AD      = data_dict['hybrid_p_l_0_5_AD']['keyrate_bps_level_0'].to_numpy()
sk_hybrid_0_5_level_1_AD      = data_dict['hybrid_p_l_0_5_AD']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_5_level_2_AD      = data_dict['hybrid_p_l_0_5_AD']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_5_GHZ_level_1  = data_dict['atom_based_GHZ_p_l_0_5_level_1']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_5_GHZ_level_1  = data_dict['hybrid_GHZ_p_l_0_5_level_1']['keyrate_bps_level_1'].to_numpy()

sk_atom_based_0_5_GHZ_level_1_AD  = data_dict['atom_based_GHZ_p_l_0_5_level_1_AD']['keyrate_bps_level_1'].to_numpy()
sk_hybrid_0_5_GHZ_level_1_AD  = data_dict['hybrid_GHZ_p_l_0_5_level_1_AD']['keyrate_bps_level_1'].to_numpy()

sk_atom_based_0_5_GHZ_level_2  = data_dict['atom_based_GHZ_p_l_0_5_level_2']['keyrate_bps_level_2'].to_numpy()
sk_hybrid_0_5_GHZ_level_2  = data_dict['hybrid_GHZ_p_l_0_5_level_2']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_5_GHZ_level_2_AD  = data_dict['atom_based_GHZ_p_l_0_5_level_2_AD']['keyrate_bps_level_2'].to_numpy()
sk_hybrid_0_5_GHZ_level_2_AD  = data_dict['hybrid_GHZ_p_l_0_5_level_2_AD']['keyrate_bps_level_2'].to_numpy()

sk_atom_based_0_5_level_0_total = sk_atom_based_0_5_level_0
sk_atom_based_0_5_level_1_total = sk_atom_based_0_5_level_1 + sk_atom_based_0_5_GHZ_level_1
sk_atom_based_0_5_level_2_total = sk_atom_based_0_5_level_2 + sk_atom_based_0_5_GHZ_level_2

sk_atom_based_0_5_level_0_AD_total = sk_atom_based_0_5_level_0_AD
sk_atom_based_0_5_level_1_AD_total = sk_atom_based_0_5_level_1_AD + sk_atom_based_0_5_GHZ_level_1_AD
sk_atom_based_0_5_level_2_AD_total = sk_atom_based_0_5_level_2_AD + sk_atom_based_0_5_GHZ_level_2_AD

sk_hybrid_0_5_level_0_total = sk_hybrid_0_5_level_0
sk_hybrid_0_5_level_1_total = sk_hybrid_0_5_level_1 + sk_hybrid_0_5_GHZ_level_1
sk_hybrid_0_5_level_2_total = sk_hybrid_0_5_level_2 + sk_hybrid_0_5_GHZ_level_2

sk_hybrid_0_5_level_0_AD_total = sk_hybrid_0_5_level_0_AD
sk_hybrid_0_5_level_1_AD_total = sk_hybrid_0_5_level_1_AD + sk_hybrid_0_5_GHZ_level_1_AD
sk_hybrid_0_5_level_2_AD_total = sk_hybrid_0_5_level_2_AD + sk_hybrid_0_5_GHZ_level_2_AD

# %%
plt.plot(d_lst, sk_atom_based_0_5_GHZ_level_2, label = 'atom-based (level 0)', linestyle = '--', color = 'C0')
plt.scatter(d_lst, sk_hybrid_0_5_GHZ_level_2, label = 'hybrid (level 0)', color = 'C0', s=8)
plt.plot(d_lst, sk_atom_based_0_5_GHZ_level_2_AD, label = 'atom-based (level 0, AD)', linestyle = '--', color = 'C1')
plt.scatter(d_lst, sk_hybrid_0_5_GHZ_level_2_AD, label = 'hybrid (level 0, AD)', color = 'C1', s=8)

# plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left')
plt.yscale('log')
plt.savefig("figure.pdf")
